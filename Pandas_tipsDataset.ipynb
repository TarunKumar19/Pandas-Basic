# %%
# Basic packages
import os
import numpy as np
import pandas as pd
os.getcwd()
# Out:
# 'C:\\Users\\ertar\\OneDrive\\Desktop\\PGA07\\PYTHON\\2nd July 2022'

# %%
# import dataset
mydata = pd.read_csv('tips.csv')
mydata.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
# What is the length of the dataset
print(len(mydata))
# Out:
# 244

# %%
# what is the row and column there in the dataset
print(mydata.shape)
# Out:
# (244, 7)

# %%
# Do we have missing data or not ?
mydata.isnull().value_counts()
# Out:
# total_bill  tip    sex    smoker  day    time   size
# False       False  False  False   False  False  False    244
# dtype: int64

# %%
mydata.isnull().any()
# Out:
# total_bill    False
# tip           False
# sex           False
# smoker        False
# day           False
# time          False
# size          False
# dtype: bool

# %%
mydata.isnull().sum()
# Out:
# total_bill    0
# tip           0
# sex           0
# smoker        0
# day           0
# time          0
# size          0
# dtype: int64

# %%
mydata.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   total_bill  244 non-null    float64
#  1   tip         244 non-null    float64
#  2   sex         244 non-null    object
#  3   smoker      244 non-null    object
#  4   day         244 non-null    object
#  5   time        244 non-null    object
#  6   size        244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
# SQL : SELECT * FROM mydata
# SQL : SELECT total_bill, sex, smoker, day from mydata

mydata[['total_bill','sex', 'smoker', 'day']].head(10)
# Out:
#    total_bill     sex smoker  day
# 0       16.99  Female     No  Sun
# 1       10.34    Male     No  Sun
# 2       21.01    Male     No  Sun
# 3       23.68    Male     No  Sun
# 4       24.59  Female     No  Sun
# 5       25.29    Male     No  Sun
# 6        8.77    Male     No  Sun
# 7       26.88    Male     No  Sun
# 8       15.04    Male     No  Sun
# 9       14.78    Male     No  Sun

# %%
mydata[['smoker', 'day','total_bill','sex']].head(10)
# Out:
#   smoker  day  total_bill     sex
# 0     No  Sun       16.99  Female
# 1     No  Sun       10.34    Male
# 2     No  Sun       21.01    Male
# 3     No  Sun       23.68    Male
# 4     No  Sun       24.59  Female
# 5     No  Sun       25.29    Male
# 6     No  Sun        8.77    Male
# 7     No  Sun       26.88    Male
# 8     No  Sun       15.04    Male
# 9     No  Sun       14.78    Male

# %%
# SQL : total_bill, day only limit 25
mydata[['total_bill','day']].head(25)
# Out:
#     total_bill  day
# 0        16.99  Sun
# 1        10.34  Sun
# 2        21.01  Sun
# 3        23.68  Sun
# 4        24.59  Sun
# 5        25.29  Sun
# 6         8.77  Sun
# 7        26.88  Sun
# 8        15.04  Sun
# 9        14.78  Sun
# 10       10.27  Sun
# 11       35.26  Sun
# 12       15.42  Sun
# 13       18.43  Sun
# 14       14.83  Sun
# 15       21.58  Sun
# 16       10.33  Sun
# 17       16.29  Sun
# 18       16.97  Sun
# 19       20.65  Sat
# 20       17.92  Sat
# 21       20.29  Sat
# 22       15.77  Sat
# 23       39.42  Sat
# 24       19.82  Sat

# %%
mydata.tail(25)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 219       30.14  3.09  Female    Yes   Sat  Dinner     4
# 220       12.16  2.20    Male    Yes   Fri   Lunch     2
# 221       13.42  3.48  Female    Yes   Fri   Lunch     2
# 222        8.58  1.92    Male    Yes   Fri   Lunch     1
# 223       15.98  3.00  Female     No   Fri   Lunch     3
# 224       13.42  1.58    Male    Yes   Fri   Lunch     2
# 225       16.27  2.50  Female    Yes   Fri   Lunch     2
# 226       10.09  2.00  Female    Yes   Fri   Lunch     2
# 227       20.45  3.00    Male     No   Sat  Dinner     4
# 228       13.28  2.72    Male     No   Sat  Dinner     2
# 229       22.12  2.88  Female    Yes   Sat  Dinner     2
# 230       24.01  2.00    Male    Yes   Sat  Dinner     4
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3
# 232       11.61  3.39    Male     No   Sat  Dinner     2
# 233       10.77  1.47    Male     No   Sat  Dinner     2
# ...

# %%
# SQL : time : Dinner
# select * from mydata where time = 'Dinner'

mydata.query('time=="Dinner"')
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [176 rows x 7 columns]

# %%
mydata[mydata['time']=='Dinner']
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [176 rows x 7 columns]

# %%
mydata[mydata['day']=='Sun']
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 0         16.99  1.01  Female     No  Sun  Dinner     2
# 1         10.34  1.66    Male     No  Sun  Dinner     3
# 2         21.01  3.50    Male     No  Sun  Dinner     3
# 3         23.68  3.31    Male     No  Sun  Dinner     2
# 4         24.59  3.61  Female     No  Sun  Dinner     4
# ..          ...   ...     ...    ...  ...     ...   ...
# 186       20.90  3.50  Female    Yes  Sun  Dinner     3
# 187       30.46  2.00    Male    Yes  Sun  Dinner     5
# 188       18.15  3.50  Female    Yes  Sun  Dinner     3
# 189       23.10  4.00    Male    Yes  Sun  Dinner     3
# 190       15.69  1.50    Male    Yes  Sun  Dinner     2
#
# [76 rows x 7 columns]

# %%
# day = Sun, time = Dinner

# %%
mydata[(mydata['day']=='Fri') & (mydata['time']=='Lunch')]
# Out:
#      total_bill   tip     sex smoker  day   time  size
# 220       12.16  2.20    Male    Yes  Fri  Lunch     2
# 221       13.42  3.48  Female    Yes  Fri  Lunch     2
# 222        8.58  1.92    Male    Yes  Fri  Lunch     1
# 223       15.98  3.00  Female     No  Fri  Lunch     3
# 224       13.42  1.58    Male    Yes  Fri  Lunch     2
# 225       16.27  2.50  Female    Yes  Fri  Lunch     2
# 226       10.09  2.00  Female    Yes  Fri  Lunch     2

# %%
# sex = Male, size >=5
mydata[(mydata['sex']=='Male') & (mydata['size']>=5)]
# Out:
#      total_bill  tip   sex smoker   day    time  size
# 141       34.30  6.7  Male     No  Thur   Lunch     6
# 142       41.19  5.0  Male     No  Thur   Lunch     5
# 156       48.17  5.0  Male     No   Sun  Dinner     6
# 185       20.69  5.0  Male     No   Sun  Dinner     5
# 187       30.46  2.0  Male    Yes   Sun  Dinner     5
# 216       28.15  3.0  Male    Yes   Sat  Dinner     5

# %%
# tip >4, sex = Female, time = 'Dinner' and size >3

# %%
mydata[(mydata['tip']>=4) & (mydata['sex']=='Female') & (mydata['time']=='Dinner') & (mydata['size']>=3)]
# Out:
#      total_bill   tip     sex smoker  day    time  size
# 11        35.26  5.00  Female     No  Sun  Dinner     4
# 52        34.81  5.20  Female     No  Sun  Dinner     4
# 114       25.71  4.00  Female     No  Sun  Dinner     3
# 155       29.85  5.14  Female     No  Sun  Dinner     5
# 214       28.17  6.50  Female    Yes  Sat  Dinner     3
# 238       35.83  4.67  Female     No  Sat  Dinner     3

# %%
# either-or : sex = Male, Time = Dinner, day = Sat
mydata[(mydata["time"] == 'Dinner') | (mydata['sex']=='Male') | (mydata["day"] == 'Sat') ]
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [209 rows x 7 columns]

# %%
# how many males and females there in the dataset

mydata.groupby('sex').size()
# Out:
# sex
# Female     87
# Male      157
# dtype: int64

# %%
mydata['sex'].value_counts()
# Out:
# Male      157
# Female     87
# Name: sex, dtype: int64

# %%
mydata.groupby(['smoker','sex']).size()
# Out:
# smoker  sex
# No      Female    54
#         Male      97
# Yes     Female    33
#         Male      60
# dtype: int64

# %%
mydata.groupby(['smoker','sex','day']).size()
# Out:
# smoker  sex     day
# No      Female  Fri      2
#                 Sat     13
#                 Sun     14
#                 Thur    25
#         Male    Fri      2
#                 Sat     32
#                 Sun     43
#                 Thur    20
# Yes     Female  Fri      7
#                 Sat     15
#                 Sun      4
#                 Thur     7
#         Male    Fri      8
#                 Sat     27
#                 Sun     15
#                 Thur    10
# dtype: int64

# %%
mydata.describe()
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
import seaborn as sns

# %%
sns.boxplot(y='total_bill', data=mydata)
# Out:
# <AxesSubplot:ylabel='total_bill'>

# %%
mydata.value_counts()
# Out:
# total_bill  tip    sex     smoker  day   time    size
# 13.00       2.00   Female  Yes     Thur  Lunch   2       2
# 3.07        1.00   Female  Yes     Sat   Dinner  1       1
# 22.23       5.00   Male    No      Sun   Dinner  2       1
# 20.69       2.45   Female  No      Sat   Dinner  4       1
#             5.00   Male    No      Sun   Dinner  5       1
#                                                         ..
# 15.53       3.00   Male    Yes     Sat   Dinner  2       1
# 15.69       1.50   Male    Yes     Sun   Dinner  2       1
#             3.00   Male    Yes     Sat   Dinner  3       1
# 15.77       2.23   Female  No      Sat   Dinner  2       1
# 50.81       10.00  Male    Yes     Sat   Dinner  3       1
# Length: 243, dtype: int64

# %%
sns.heatmap(mydata.corr(), annot=True, cmap='coolwarm')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(mydata.corr())
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(mydata.corr(),annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(mydata.corr(),annot=True, cmap = 'rainbow')
# Out:
# <AxesSubplot:>

# %%
sns.heatmap(mydata.corr(),annot=True, cmap = 'YlGnBu')
# Out:
# <AxesSubplot:>

# %%
mydata.plot()
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(mydata)
